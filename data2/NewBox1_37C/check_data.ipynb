# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('TableofData_SatP3SatT6000.csv')

z1 = df.iloc[1,14::] / df.iloc[1,12]
z2 = df.iloc[-1,14::] / df.iloc[-1,12]
z1.plot()
z2.plot()
plt.legend([str(df.pH[1]),str(df.pH.values[-1])])

# %%
df[['pH', 'Conc(mM)', 'ApproT1(sec)', 'ExpT1(ms)', 'ExpT2(ms)',
       'ExpB1(percent)', 'ExpB0(ppm)', 'ExpB0(Hz)', 'Temp', 'SatPower(uT)',
       'SatTime(ms)']].nunique()
# Out:
# pH                21
# Conc(mM)          18
# ApproT1(sec)       3
# ExpT1(ms)         24
# ExpT2(ms)         24
# ExpB1(percent)    24
# ExpB0(ppm)        24
# ExpB0(Hz)         24
# Temp               1
# SatPower(uT)       1
# SatTime(ms)        1
# dtype: int64

# %%
df['Conc(mM)'].value_counts()
# Out:
# 24.943    3
# 24.915    3
# 24.965    2
# 24.831    2
# 24.918    1
# 24.772    1
# 24.755    1
# 24.908    1
# 24.735    1
# 24.543    1
# 24.950    1
# 24.704    1
# 24.975    1
# 24.933    1
# 24.938    1
# 24.893    1
# 24.846    1
# 24.935    1
# Name: Conc(mM), dtype: int64

# %%
# Out:
# 7.3
